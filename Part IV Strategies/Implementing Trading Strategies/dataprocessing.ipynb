# %%
import pandas as pd

# %%
df = pd.read_csv('Reliance_20_to_24.csv')
df
# Out:
#             Date        close         open         High          low    volume
# 0     2020-01-01   675.956609   680.008790   670.390471   672.216125  14004468
# 1     2020-01-02   673.284921   686.176208   673.284921   683.660278  17710316
# 2     2020-01-03   682.636001   686.487835   678.183067   684.484009  20984698
# 3     2020-01-06   676.847260   680.365044   667.050769   668.609314  24519177
# 4     2020-01-07   676.401873   683.303975   673.952766   678.895569  16683622
# ...          ...          ...          ...          ...          ...       ...
# 1232  2024-12-23  1204.597171  1216.692666  1202.812534  1211.834717  10052824
# 1233  2024-12-24  1211.834785  1222.988463  1210.545867  1212.280884   6734917
# 1234  2024-12-26  1213.767935  1217.188348  1203.853555  1206.133911  10016178
# 1235  2024-12-27  1207.869004  1217.386785  1206.580087  1210.595459   7000397
# 1236  2024-12-30  1205.985131  1212.726837  1197.756148  1200.333862   8818766
#
# [1237 rows x 6 columns]

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df = df.set_index(['Date'])

# %%
df.to_csv('Reliance_20_to_24.csv')
